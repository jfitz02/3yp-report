# %%
import tweepy

token_dict = {}
with open("pass.secret", 'r') as f:
    for line in f:
        parts = line.split("=")
        token_dict[parts[0].strip()] = parts[1].strip()

api = tweepy.Client(token_dict["bearer_token"], consumer_key=token_dict["consumer_key"],
                    consumer_secret=token_dict["consumer_secret"], access_token=token_dict["access_token"],
                    access_token_secret=token_dict["access_token_secret"])

print(api.get_tweet(1177626185624379395, tweet_fields=["author_id","conversation_id","in_reply_to_user_id","referenced_tweets"],
                                            expansions=["author_id", "in_reply_to_user_id", "referenced_tweets.id"]))
# Out:
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# Cell In[17], line 13
#       7         token_dict[parts[0].strip()] = parts[1].strip()
#       9 api = tweepy.Client(token_dict["bearer_token"], consumer_key=token_dict["consumer_key"],
#      10                     consumer_secret=token_dict["consumer_secret"], access_token=token_dict["access_token"],
#      11                     access_token_secret=token_dict["access_token_secret"])
# ---> 13 print(api.get_tweet(1177626185624379395, tweet_fields=["author_id","conversation_id","in_reply_to_user_id","referenced_tweets"],
#      14                                             expansions=["author_id", "in_reply_to_user_id", "referenced_tweets.id", "conversation_id"]))
#
# File c:\Users\jfitz\OneDrive\Documents\3rd year project\code\venv\lib\site-packages\tweepy\client.py:1755, in Client.get_tweet(self, id, user_auth, **params)
# ...

# %% [markdown]
# Status(_api=<tweepy.api.API object at 0x0000025FC6563730>, _json={'created_at': 'Fri Jan 27 16:18:05 +0000 2023', 'id': 1619006841941524481, 'id_str': '1619006841941524481', 'text': 'Everything looks cooler in black and white. 📸🖤🤍 https://t.co/qrDjziVcSn', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [], 'media': [{'id': 1619006662504767491, 'id_str': '1619006662504767491', 'indices': [48, 71], 'media_url': 'http://pbs.twimg.com/media/Fnfd-0-WYAMUp5W.jpg', 'media_url_https': 'https://pbs.twimg.com/media/Fnfd-0-WYAMUp5W.jpg', 'url': 'https://t.co/qrDjziVcSn', 'display_url': 'pic.twitter.com/qrDjziVcSn', 'expanded_url': 'https://twitter.com/MercedesAMGF1/status/1619006841941524481/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 383, 'h': 680, 'resize': 'fit'}, 'medium': {'w': 675, 'h': 1200, 'resize': 'fit'}, 'large': {'w': 1152, 'h': 2048, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 1619006662504767491, 'id_str': '1619006662504767491', 'indices': [48, 71], 'media_url': 'http://pbs.twimg.com/media/Fnfd-0-WYAMUp5W.jpg', 'media_url_https': 'https://pbs.twimg.com/media/Fnfd-0-WYAMUp5W.jpg', 'url': 'https://t.co/qrDjziVcSn', 'display_url': 'pic.twitter.com/qrDjziVcSn', 'expanded_url': 'https://twitter.com/MercedesAMGF1/status/1619006841941524481/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 383, 'h': 680, 'resize': 'fit'}, 'medium': {'w': 675, 'h': 1200, 'resize': 'fit'}, 'large': {'w': 1152, 'h': 2048, 'resize': 'fit'}}}, {'id': 1619006744541134848, 'id_str': '1619006744541134848', 'indices': [48, 71], 'media_url': 'http://pbs.twimg.com/media/FnfeDmlWAAAsd0L.jpg', 'media_url_https': 'https://pbs.twimg.com/media/FnfeDmlWAAAsd0L.jpg', 'url': 'https://t.co/qrDjziVcSn', 'display_url': 'pic.twitter.com/qrDjziVcSn', 'expanded_url': 'https://twitter.com/MercedesAMGF1/status/1619006841941524481/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 1366, 'h': 2048, 'resize': 'fit'}, 'medium': {'w': 800, 'h': 1200, 'resize': 'fit'}, 'small': {'w': 453, 'h': 680, 'resize': 'fit'}}}]}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 26235265, 'id_str': '26235265', 'name': 'Mercedes-AMG PETRONAS F1 Team', 'screen_name': 'MercedesAMGF1', 'location': 'Brackley, England', 'description': 'W14 E PERFORMANCE Launch 🗓️ 15.02.23', 'url': 'https://t.co/jamtyrsMKk', 'entities': {'url': {'urls': [{'url': 'https://t.co/jamtyrsMKk', 'expanded_url': 'https://linktr.ee/mercedesamgf1', 'display_url': 'linktr.ee/mercedesamgf1', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 4556397, 'friends_count': 3697, 'listed_count': 40036, 'created_at': 'Tue Mar 24 13:24:04 +0000 2009', 'favourites_count': 119233, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': True, 'statuses_count': 137113, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1544991428840939521/a6V_z4ky_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1544991428840939521/a6V_z4ky_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/26235265/1674057666', 'profile_link_color': '00A19C', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'EDEDED', 'profile_text_color': '333333', 'profile_use_background_image': False, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 649, 'favorite_count': 10906, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'possibly_sensitive_appealable': False, 'lang': 'en'}, created_at=datetime.datetime(2023, 1, 27, 16, 18, 5, tzinfo=datetime.timezone.utc), id=1619006841941524481, id_str='1619006841941524481', text='Everything looks cooler in black and white. 📸🖤🤍 https://t.co/qrDjziVcSn', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [], 'media': [{'id': 1619006662504767491, 'id_str': '1619006662504767491', 'indices': [48, 71], 'media_url': 'http://pbs.twimg.com/media/Fnfd-0-WYAMUp5W.jpg', 'media_url_https': 'https://pbs.twimg.com/media/Fnfd-0-WYAMUp5W.jpg', 'url': 'https://t.co/qrDjziVcSn', 'display_url': 'pic.twitter.com/qrDjziVcSn', 'expanded_url': 'https://twitter.com/MercedesAMGF1/status/1619006841941524481/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 383, 'h': 680, 'resize': 'fit'}, 'medium': {'w': 675, 'h': 1200, 'resize': 'fit'}, 'large': {'w': 1152, 'h': 2048, 'resize': 'fit'}}}]}, extended_entities={'media': [{'id': 1619006662504767491, 'id_str': '1619006662504767491', 'indices': [48, 71], 'media_url': 'http://pbs.twimg.com/media/Fnfd-0-WYAMUp5W.jpg', 'media_url_https': 'https://pbs.twimg.com/media/Fnfd-0-WYAMUp5W.jpg', 'url': 'https://t.co/qrDjziVcSn', 'display_url': 'pic.twitter.com/qrDjziVcSn', 'expanded_url': 'https://twitter.com/MercedesAMGF1/status/1619006841941524481/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 383, 'h': 680, 'resize': 'fit'}, 'medium': {'w': 675, 'h': 1200, 'resize': 'fit'}, 'large': {'w': 1152, 'h': 2048, 'resize': 'fit'}}}, {'id': 1619006744541134848, 'id_str': '1619006744541134848', 'indices': [48, 71], 'media_url': 'http://pbs.twimg.com/media/FnfeDmlWAAAsd0L.jpg', 'media_url_https': 'https://pbs.twimg.com/media/FnfeDmlWAAAsd0L.jpg', 'url': 'https://t.co/qrDjziVcSn', 'display_url': 'pic.twitter.com/qrDjziVcSn', 'expanded_url': 'https://twitter.com/MercedesAMGF1/status/1619006841941524481/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 1366, 'h': 2048, 'resize': 'fit'}, 'medium': {'w': 800, 'h': 1200, 'resize': 'fit'}, 'small': {'w': 453, 'h': 680, 'resize': 'fit'}}}]}, source='Twitter Web App', source_url='https://mobile.twitter.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x0000025FC6563730>, _json={'id': 26235265, 'id_str': '26235265', 'name': 'Mercedes-AMG PETRONAS F1 Team', 'screen_name': 'MercedesAMGF1', 'location': 'Brackley, England', 'description': 'W14 E PERFORMANCE Launch 🗓️ 15.02.23', 'url': 'https://t.co/jamtyrsMKk', 'entities': {'url': {'urls': [{'url': 'https://t.co/jamtyrsMKk', 'expanded_url': 'https://linktr.ee/mercedesamgf1', 'display_url': 'linktr.ee/mercedesamgf1', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 4556397, 'friends_count': 3697, 'listed_count': 40036, 'created_at': 'Tue Mar 24 13:24:04 +0000 2009', 'favourites_count': 119233, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': True, 'statuses_count': 137113, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1544991428840939521/a6V_z4ky_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1544991428840939521/a6V_z4ky_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/26235265/1674057666', 'profile_link_color': '00A19C', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'EDEDED', 'profile_text_color': '333333', 'profile_use_background_image': False, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, id=26235265, id_str='26235265', name='Mercedes-AMG PETRONAS F1 Team', screen_name='MercedesAMGF1', location='Brackley, England', description='W14 E PERFORMANCE Launch 🗓️ 15.02.23', url='https://t.co/jamtyrsMKk', entities={'url': {'urls': [{'url': 'https://t.co/jamtyrsMKk', 'expanded_url': 'https://linktr.ee/mercedesamgf1', 'display_url': 'linktr.ee/mercedesamgf1', 'indices': [0, 23]}]}, 'description': {'urls': []}}, protected=False, followers_count=4556397, friends_count=3697, listed_count=40036, created_at=datetime.datetime(2009, 3, 24, 13, 24, 4, tzinfo=datetime.timezone.utc), favourites_count=119233, utc_offset=None, time_zone=None, geo_enabled=True, verified=True, statuses_count=137113, lang=None, contributors_enabled=False, is_translator=False, is_translation_enabled=False, profile_background_color='000000', profile_background_image_url='http://abs.twimg.com/images/themes/theme1/bg.png', profile_background_image_url_https='https://abs.twimg.com/images/themes/theme1/bg.png', profile_background_tile=False, profile_image_url='http://pbs.twimg.com/profile_images/1544991428840939521/a6V_z4ky_normal.jpg', profile_image_url_https='https://pbs.twimg.com/profile_images/1544991428840939521/a6V_z4ky_normal.jpg', profile_banner_url='https://pbs.twimg.com/profile_banners/26235265/1674057666', profile_link_color='00A19C', profile_sidebar_border_color='FFFFFF', profile_sidebar_fill_color='EDEDED', profile_text_color='333333', profile_use_background_image=False, has_extended_profile=False, default_profile=False, default_profile_image=False, following=False, follow_request_sent=False, notifications=False, translator_type='none', withheld_in_countries=[]), user=User(_api=<tweepy.api.API object at 0x0000025FC6563730>, _json={'id': 26235265, 'id_str': '26235265', 'name': 'Mercedes-AMG PETRONAS F1 Team', 'screen_name': 'MercedesAMGF1', 'location': 'Brackley, England', 'description': 'W14 E PERFORMANCE Launch 🗓️ 15.02.23', 'url': 'https://t.co/jamtyrsMKk', 'entities': {'url': {'urls': [{'url': 'https://t.co/jamtyrsMKk', 'expanded_url': 'https://linktr.ee/mercedesamgf1', 'display_url': 'linktr.ee/mercedesamgf1', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 4556397, 'friends_count': 3697, 'listed_count': 40036, 'created_at': 'Tue Mar 24 13:24:04 +0000 2009', 'favourites_count': 119233, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': True, 'statuses_count': 137113, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1544991428840939521/a6V_z4ky_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1544991428840939521/a6V_z4ky_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/26235265/1674057666', 'profile_link_color': '00A19C', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'EDEDED', 'profile_text_color': '333333', 'profile_use_background_image': False, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, id=26235265, id_str='26235265', name='Mercedes-AMG PETRONAS F1 Team', screen_name='MercedesAMGF1', location='Brackley, England', description='W14 E PERFORMANCE Launch 🗓️ 15.02.23', url='https://t.co/jamtyrsMKk', entities={'url': {'urls': [{'url': 'https://t.co/jamtyrsMKk', 'expanded_url': 'https://linktr.ee/mercedesamgf1', 'display_url': 'linktr.ee/mercedesamgf1', 'indices': [0, 23]}]}, 'description': {'urls': []}}, protected=False, followers_count=4556397, friends_count=3697, listed_count=40036, created_at=datetime.datetime(2009, 3, 24, 13, 24, 4, tzinfo=datetime.timezone.utc), favourites_count=119233, utc_offset=None, time_zone=None, geo_enabled=True, verified=True, statuses_count=137113, lang=None, contributors_enabled=False, is_translator=False, is_translation_enabled=False, profile_background_color='000000', profile_background_image_url='http://abs.twimg.com/images/themes/theme1/bg.png', profile_background_image_url_https='https://abs.twimg.com/images/themes/theme1/bg.png', profile_background_tile=False, profile_image_url='http://pbs.twimg.com/profile_images/1544991428840939521/a6V_z4ky_normal.jpg', profile_image_url_https='https://pbs.twimg.com/profile_images/1544991428840939521/a6V_z4ky_normal.jpg', profile_banner_url='https://pbs.twimg.com/profile_banners/26235265/1674057666', profile_link_color='00A19C', profile_sidebar_border_color='FFFFFF', profile_sidebar_fill_color='EDEDED', profile_text_color='333333', profile_use_background_image=False, has_extended_profile=False, default_profile=False, default_profile_image=False, following=False, follow_request_sent=False, notifications=False, translator_type='none', withheld_in_countries=[]), geo=None, coordinates=None, place=None, contributors=None, is_quote_status=False, retweet_count=649, favorite_count=10906, favorited=False, retweeted=False, possibly_sensitive=False, possibly_sensitive_appealable=False, lang='en')
